# %%
# run this if using colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# This notebook can be used to view histograms of distances between inter (same type) and intra part (same instance) impedance signatures represented as bit strings.

# %%
import os 
if os.getcwd() == "/content":
    BASE = os.path.join(os.getcwd(), "drive", "MyDrive", "matcher")
    os.chdir(BASE) # os.chdir("/") for reset
print(os.getcwd())
# print(os.getcwd())
# Out:
# /content/drive/MyDrive/matcher

# %%
from match import * # run above cell if module not found

# %% [markdown]
# Read files and prep data (supports csv, txt, npy, and xls)

# %%
group = "orig" # should be one of ["all", "test", "multi", "orig"]
assert group in GROUPS
SIZE = 200 # should be in [1, 4000], the number of responses to compare

# get data location
dir, fls, parts = getDirectory(group)

# collect data to plot in histogram
if group == "all":
    data = run(dir, fls, parts, SIZE)
else:
    data = run(dir, os.listdir(dir), parts, SIZE)
# Out:
# group test
# ...

# %% [markdown]
# Plot the results

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 8] # adjust size [w, h] (inches)

# %%
makeHistograms(data, parts, SIZE)
# Out:
# len data 5
# ax len (5, 2)
